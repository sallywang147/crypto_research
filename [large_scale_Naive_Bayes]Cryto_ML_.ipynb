# %% [markdown]
# <a href="https://colab.research.google.com/github/sallywang147/crypto_research/blob/main/%5Blarge_scale_Naive_Bayes%5DCryto_ML_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Imports
#
# We import the necessary ML libraries to help us build machine learning models:

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import sklearn.linear_model
import scipy as sp
from sklearn.metrics import accuracy_score
from sklearn.metrics import balanced_accuracy_score
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn import naive_bayes
# %config InlineBackend.figure_format = 'retina'

# %%
# !wget https://www.dropbox.com/s/rywpe2u5sg3qy3f/randata.txt?dl=0
# !wget https://www.dropbox.com/s/pnmg49j5w3ebjlh/datafile.txt?dl=0
# Out:
# --2023-02-22 23:56:02--  https://www.dropbox.com/s/rywpe2u5sg3qy3f/randata.txt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.6.18, 2620:100:601c:18::a27d:612
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.6.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/rywpe2u5sg3qy3f/randata.txt [following]
# --2023-02-22 23:56:02--  https://www.dropbox.com/s/raw/rywpe2u5sg3qy3f/randata.txt
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc4d87e6fb96653e898e3862f4cd.dl.dropboxusercontent.com/cd/0/inline/B3DvfOQyop9HUp0e0CseydbEeXc_lk9jHMS8W51yz4t04mnxrGdVp98VDzuQF7QXOAWO-vOE4atA1B3goB0urbF_Z9wYdr0D3zb9a454hFG-mBFdXgK3NOkI-73kXhjsMF5QCyaNcII-sADSBw-FY9kYtVYPvRt1hsMwi2rY-XnExg/file# [following]
# --2023-02-22 23:56:02--  https://uc4d87e6fb96653e898e3862f4cd.dl.dropboxusercontent.com/cd/0/inline/B3DvfOQyop9HUp0e0CseydbEeXc_lk9jHMS8W51yz4t04mnxrGdVp98VDzuQF7QXOAWO-vOE4atA1B3goB0urbF_Z9wYdr0D3zb9a454hFG-mBFdXgK3NOkI-73kXhjsMF5QCyaNcII-sADSBw-FY9kYtVYPvRt1hsMwi2rY-XnExg/file
# Resolving uc4d87e6fb96653e898e3862f4cd.dl.dropboxusercontent.com (uc4d87e6fb96653e898e3862f4cd.dl.dropboxusercontent.com)... 162.125.6.15, 2620:100:601c:15::a27d:60f
# Connecting to uc4d87e6fb96653e898e3862f4cd.dl.dropboxusercontent.com (uc4d87e6fb96653e898e3862f4cd.dl.dropboxusercontent.com)|162.125.6.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 420646871 (401M) [text/plain]
# Saving to: ‘randata.txt?dl=0’
#
# randata.txt?dl=0    100%[===================>] 401.16M   165MB/s    in 2.4s
#
# 2023-02-22 23:56:05 (165 MB/s) - ‘randata.txt?dl=0’ saved [420646871/420646871]
#
# --2023-02-22 23:56:05--  https://www.dropbox.com/s/pnmg49j5w3ebjlh/datafile.txt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.6.18, 2620:100:601c:18::a27d:612
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.6.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/pnmg49j5w3ebjlh/datafile.txt [following]
# --2023-02-22 23:56:05--  https://www.dropbox.com/s/raw/pnmg49j5w3ebjlh/datafile.txt
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc4ba447e4910c6d588ba074885b.dl.dropboxusercontent.com/cd/0/inline/B3ANKoO3GIxZRfF4zxkqaYJu5R64oA9Mm4hlIMR7ftRxo5Pf5a4HXlja0Dw-MCfswn12OZwBebtN3Gbhmcl5zW6wsB9v_L_ucpaBl2SQWhiuGssLvFODymEmagqGsb8A2Q3RiILBFoTP-IRiATbOh5X6b1b0GGiKl_gcO3PLAMJsRw/file# [following]
# --2023-02-22 23:56:05--  https://uc4ba447e4910c6d588ba074885b.dl.dropboxusercontent.com/cd/0/inline/B3ANKoO3GIxZRfF4zxkqaYJu5R64oA9Mm4hlIMR7ftRxo5Pf5a4HXlja0Dw-MCfswn12OZwBebtN3Gbhmcl5zW6wsB9v_L_ucpaBl2SQWhiuGssLvFODymEmagqGsb8A2Q3RiILBFoTP-IRiATbOh5X6b1b0GGiKl_gcO3PLAMJsRw/file
# Resolving uc4ba447e4910c6d588ba074885b.dl.dropboxusercontent.com (uc4ba447e4910c6d588ba074885b.dl.dropboxusercontent.com)... 162.125.6.15, 2620:100:601c:15::a27d:60f
# Connecting to uc4ba447e4910c6d588ba074885b.dl.dropboxusercontent.com (uc4ba447e4910c6d588ba074885b.dl.dropboxusercontent.com)|162.125.6.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 420645234 (401M) [text/plain]
# Saving to: ‘datafile.txt?dl=0’
#
# datafile.txt?dl=0   100%[===================>] 401.16M   119MB/s    in 3.4s
#
# 2023-02-22 23:56:09 (119 MB/s) - ‘datafile.txt?dl=0’ saved [420645234/420645234]

# %%
encrypt_data = pd.read_csv('datafile.txt?dl=0', sep=',', header=None)
random_data = pd.read_csv('randata.txt?dl=0', sep=',',  header=None)

# %%
encrypt_data.drop(columns=encrypt_data.columns[-1], axis=1, inplace=True)
random_data.drop(columns=random_data.columns[-1], axis=1, inplace=True)

# %%
encrypt_data
# Out:
#                     0                 1                 2                 3    \
# 0       982020383572593  1111247943234836   382283942275718    15419645768696
# 1       264242486510830   404255959612560   599362681771941   927038368360771
# 2       755714025544024   595302336706326   188001124610168   682117400467822
# 3       581907315344320   926196942276883   873668862213476   526355527718876
# 4       404684052869976   731430739230845    70883601845658  1082449066411564
# ...                 ...               ...               ...               ...
# 51195   251963708623232   909891036904025   584937610699902   433720453531503
# 51196  1084140105246507   568538137257260   867691546896628   762135257727097
# 51197   566952340518048   107935008926358    51919646111205   918311125636632
# 51198   122187339106035   270255637816795   518714197600047   454517363513461
# 51199   481174757512894   501242924061121  1119114944583075   708152453707219
#
#                     4                 5                 6                 7    \
# 0       401696546541716   300703115494301  1032820603622192   906441900615720
# 1       256651885938646    24798171362603    78182410755500   240102103118369
# 2       806959201802402   355879884496907    82762741418634   424489090634543
# 3      1087664651115869   492718866769664   678271026559970   560311471139995
# 4       555807239916545   390362934680003   865357395146866   762705094836439
# ...                 ...               ...               ...               ...
# 51195   393909267396917   562663251283099   467780320170444   515268309250136
# 51196   480332317304727   286670305438967   780287221777872   649002078588696
# 51197  1059966437920058   703055399780115   648508218209634   555066558270713
# 51198   178950919939340  1056272147950917   840422624254175   894943372421351
# 51199    69408056027520   759115302672641   644776645552164  1117238366816779
#
#                     8                 9    ...               503  \
# 0       682652117114232   501294036268560  ...   619152853524440
# 1         7813860872234   192614481784318  ...   478877275897948
# 2       643468390941489   750152351534530  ...  1017055312139120
# 3       640316550420334   663799652949175  ...  1029512638862054
# 4       387979030739513  1069335843482273  ...   138039926856276
# ...                 ...               ...  ...               ...
# 51195   969394133572292   713808985020758  ...   898334968285026
# 51196   105679491238448   441832630942545  ...   249228918962664
# 51197     1489512579440   408638512457816  ...  1122316397414725
# 51198  1064865916781346   459035727858861  ...   642267431470445
# 51199    41124924543145   913498614610785  ...   499431990956193
#
#                     504               505               506              507  \
# 0       343151587298530  1052144553210660   295289749404995  494444979458155
# 1        60178121499599   796961834747793   991506112476409  877744519560415
# 2       564506137974228   278095129950432    61888613633682   84170006520094
# 3       729758960121824   922635344633037   257601251200254  193666913598741
# 4       927707904826860   932258490977316   539729993973319  650290587884512
# ...                 ...               ...               ...              ...
# 51195   989253923364929   228024304236616   776434133242781  104622205227043
# 51196   151671034484802   190558318129081   481439258348347  342392070943748
# 51197   866734333404798   449714516838934   492714108067192  934600655729735
# 51198   129313975059983   700066774526367   829946393741493  765465348166926
# 51199  1022053543017841   456451904775374  1108939768284528  774020716525217
#
#                     508              509               510               511  \
# 0       875000435778186  699007426498141  1117432046980664   175187627227823
# 1      1000014145397361   58178880319702    61829512835473   163183266317085
# 2        57800158789134  867135154808654   297041551826554   245079047451653
# 3       983214381774328  851029772953145   344349160844182   548471173246201
# 4       266306843596047  318158656223390   578598564536172  1111186369872404
# ...                 ...              ...               ...               ...
# 51195   134379314922832  186813706106859   174318401753819    13941716125597
# 51196   345917395652188  177855584900455   501651226903603    59615988937247
# 51197   346463414525446  403586017093777    94429876714210   975459217868894
# 51198    71495039437495  110236213753130  1073614088025569   713474867193797
# 51199    20823233215521  829362407179596   380899960037523   941656417286862
#
#                     512
# 0       959930814855219
# 1       563618060881593
# 2       662239371851992
# 3       621852353536790
# 4       434567826987699
# ...                 ...
# 51195  1015979691280139
# 51196    11649392261213
# 51197   157350612642834
# 51198   584302441112517
# 51199   986077909939818
#
# [51200 rows x 513 columns]

# %%
random_data
# Out:
#                     0                 1                 2                3    \
# 0       997087136257626   733734847770383   756529972608378  926961853559245
# 1      1113262122347071   940493709579282   706281647567409  943535328111219
# 2       464602568210930  1031612006107826   174002607366232  832416832404257
# 3       696476167618719   952985005683173   313809010350654  425896287652184
# 4       385223778737983   840820980001105   554549270980835  271114403058896
# ...                 ...               ...               ...              ...
# 51195  1042180485435322   842244168525815  1053708539816598  603307264208638
# 51196   977001418588400   100228501884679   919945813189971   66468729729867
# 51197   842689801388927   856262058840146   267616533649818   89452338102873
# 51198   417591554270427   688475729281063   407568402630453   47039653641160
# 51199   845081532412448  1050289920045528    72250642783690  749760466811137
#
#                     4                 5                 6                 7    \
# 0      1114290979007770    94016651095752   107228285729676    65495218649011
# 1       935361589304244   249498221611565   829401984356537    11222148031546
# 2        96500076626644   313633063387345   395869719124617   608258514111970
# 3       811724776560309   910316033003928   513127029098817  1028589414016007
# 4       215572865068132   486121511985209  1114114386242379   547887970684516
# ...                 ...               ...               ...               ...
# 51195   937102470079593   648855489968917   637097312719663   267796069777527
# 51196   552989351808854  1101632999349662   449944912090573  1083305323214228
# 51197   254606898978060   427584442743300   428000697506837   706139519782201
# 51198   720539437451763    83927025782999   396409146347095   741714527012689
# 51199   633661061101748   260916160704079   393351295049386    70310131421211
#
#                    8                 9    ...               503  \
# 0      870231297406895   203634558372113  ...   885607665865227
# 1      563158207814909   286803939978606  ...   657928045613087
# 2      240202606629287   390966846161977  ...   712165672866199
# 3      357093949917064   498672561180784  ...    51204801958541
# 4      477866735190143    60745430779163  ...   187350896198682
# ...                ...               ...  ...               ...
# 51195  238245943507871   728060312610438  ...   376395052004153
# 51196  636400742012169   869512032072227  ...   767981390591207
# 51197  491313560257083  1013762742357288  ...   806470478691106
# 51198  998172208705899   296336438072161  ...  1011344064490924
# 51199  359506704085910  1089050351229032  ...   317801362218700
#
#                    504               505              506               507  \
# 0      406041374196599    26074402908852  203756634590136   986099537859985
# 1      345882353295351   223425940980625  840714296247609   902245337619117
# 2      712295203181125  1090782662944157  783871064284143   537852251142490
# 3       44899975639799  1024193207591520  531932014667414   907585886068918
# 4      696154879600695   560480567381671  126888408940152   432616711450102
# ...                ...               ...              ...               ...
# 51195  945094240473027   923134420674064  118147146608568   520060429391263
# 51196  844160494635408   726916425514726  466927410555592    95620825311342
# 51197  424206348718692   574822634561920  873014164689469   973845353006719
# 51198  639687373145743  1082866445723149  588006161956833    15726613581745
# 51199  268486083181921   529058842700752  565660034788651  1061782447276090
#
#                    508               509              510              511  \
# 0      939213064406257   616354408199097    2491306898144   73921466918527
# 1      570493523264387   294234529672761  525391410979085  487396518424175
# 2      516410748151711   993861291631966  342731886648035  414342546059302
# 3      771580834990756  1117178961704791  116832520818918  182592990930898
# 4       64420598467841   181670803040459  492324500588661   43237984566044
# ...                ...               ...              ...              ...
# 51195  359303450700362   639410755471597  122496883690720  454012187785543
# 51196   10494263666848   114011549028099  653552856995942  730176384791784
# 51197   24509519995772   334758447733117  587535862516600  458404707670620
# 51198  509419378201265   767898463490229  217023284255720  942954817455233
# 51199  456240747287485   786733795267512  917929238085399   83462409322456
#
#                     512
# 0       763938116125161
# 1        53170850274295
# 2      1102204642686550
# 3        57715954194443
# 4      1038116321722129
# ...                 ...
# 51195   307330004314164
# 51196   513983907096992
# 51197  1060364330970353
# 51198   546838455569157
# 51199   589421148666805
#
# [51200 rows x 513 columns]

# %%
#we create a list of 1's that confirms the datapoints generated by encryption
#encryption scheme is true

#we create a list a 0's that confirms the randomized datapoints are indeed randomized 
#we'll append 1's and 0's to the data enctry based on how the entry is generated 

#we do so, because it's eaisier for classifier 
enc_df = pd.DataFrame()
non_enc_df = pd.DataFrame()
encrypted = np.ones((len(encrypt_data),), dtype=int)
randomized = np.zeros((len(random_data),), dtype=int)
enc_df['Encrypted'] = encrypted.tolist()
non_enc_df['Encrypted'] = randomized.tolist()

# %%
def name_columns(df):
  count = 0
  for index in range(513):
    count += 1
    df = df.rename(columns={ df.columns[index]: 'Vector'+str(count)})
  df.columns = [*df.columns[:-1], 'Encrypted']
  return df

# %%
def vectorize_columns(df):
  vectorized_df = pd.DataFrame()
  vectorized_df['Vector'] = df.values.tolist()
  return vectorized_df

# %%
from sklearn.preprocessing import StandardScaler
def standardize(df):
  std_df = df.copy(deep=True)
  scaler = StandardScaler()
  scaler.fit(std_df)
  std_df = pd.DataFrame(scaler.transform(std_df))
  return std_df

# %%
std_enc = standardize(encrypt_data)
std_rand= standardize(random_data)

# %%
#temp = encrypt_data.append(random_data, ignore_index=True)
#std_df = standardize(temp)
encrypted = enc_df.append(non_enc_df,ignore_index=True)
df1 = pd.merge(std_enc, enc_df, left_index=True, right_index=True)
df2 = pd.merge(std_rand, non_enc_df, left_index=True, right_index=True)
df = df1.append(df2, ignore_index=True)
df = name_columns(df)
#df = pd.merge(std_df, encrypted, left_index=True, right_index=True)
df
# Out:
#          Vector1   Vector2   Vector3   Vector4   Vector5   Vector6   Vector7  \
# 0       1.294327  1.688595 -0.555490 -1.685741 -0.491467 -0.813973  1.443164
# 1      -0.911476 -0.480300  0.113172  1.118341 -0.937221 -1.662197 -1.485834
# 2       0.598865  0.105788 -1.153934  0.364979  0.753995 -0.644341 -1.471781
# 3       0.064740  1.120899  0.958111 -0.114134  1.616665 -0.223652  0.355343
# 4      -0.479885  0.523400 -1.514688  1.596375 -0.017851 -0.538328  0.929357
# ...          ...       ...       ...       ...       ...       ...       ...
# 102395  1.475603  0.858040  1.511789  0.126162  1.146227  0.258535  0.220512
# 102396  1.274820 -1.428992  1.101508 -1.517167 -0.036072  1.647710 -0.353653
# 102397  0.861077  0.901246 -0.899337 -1.446811 -0.954492 -0.420350 -0.420976
# 102398 -0.448428  0.384097 -0.470072 -1.576641  0.479647 -1.474732 -0.517896
# 102399  0.868444  1.499276 -1.498569  0.574473  0.212236 -0.931708 -0.527277
#
#          Vector8   Vector9  Vector10  ...  Vector505  Vector506  Vector507  \
# 0       1.061790  0.376912 -0.190834  ...  -0.679431   1.506575  -0.821371
# 1      -0.990281 -1.705170 -1.139903  ...  -1.547713   0.722398   1.318539
# 2      -0.422440  0.256018  0.574309  ...  -0.000221  -0.872080  -1.538759
# 3      -0.004159  0.246294  0.308808  ...   0.506845   1.108593  -0.937211
# 4       0.619136 -0.532245  1.555673  ...   1.114236   1.138165  -0.070052
# ...          ...       ...       ...  ...        ...        ...        ...
# 102395 -0.916821 -0.994676  0.514475  ...   1.174975   1.111251  -1.362098
# 102396  1.596915  0.228253  0.950678  ...   0.865769   0.507667  -0.290835
# 102397  0.434334 -0.217381  1.395513  ...  -0.420744   0.039813   0.956442
# 102398  0.543991  1.339431 -0.816858  ...   0.239373   1.602601   0.081053
# 102399 -1.525554 -0.622224  1.627682  ...  -0.897786  -0.100960   0.012418
#
#         Vector508  Vector509  Vector510  Vector511  Vector512  Vector513  \
# 0       -0.213555   0.958401   0.420779   1.703514  -1.191254   1.226843
# 1        0.963657   1.343131  -1.549415  -1.531679  -1.228156   0.006178
# 2       -1.473616  -1.556533   0.937679  -0.810805  -0.976400   0.309937
# 3       -1.137322   1.291430   0.888163  -0.665817  -0.043742   0.185542
# 4        0.265087  -0.914854  -0.750121   0.052106   1.686103  -0.391304
# ...           ...        ...        ...        ...        ...        ...
# 102395  -0.130291  -0.623347   0.238493  -1.366756  -0.327715  -0.788182
# 102396  -1.436229  -1.696596  -1.374144   0.267273   0.524006  -0.152561
# 102397   1.265938  -1.653472  -0.696594   0.064142  -0.314168   1.527982
# 102398  -1.682052  -0.161456   0.632867  -1.075904   1.180237  -0.051508
# 102399   1.536507  -0.325081   0.690680   1.080744  -1.470530   0.079467
#
#         Encrypted
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1
# ...           ...
# 102395          0
# 102396          0
# 102397          0
# 102398          0
# 102399          0
#
# [102400 rows x 514 columns]

# %%
from sklearn.tree import DecisionTreeClassifier
def trainer(x_train, y_train):
  model = DecisionTreeClassifier()
  model.fit(x_train, y_train)         
  return model

# %%
def evaluate_model(df, trainer_fn, training_sizes, num_runs):
  result = np.zeros(len(training_sizes))
  predicted_label = 'Encrypted'
  for i in range(0, len(training_sizes)):
    x_train, x_test, y_train, y_test = train_test_split(
        df.drop([predicted_label], axis=1), 
        df[predicted_label], 
        test_size=0.2,
        shuffle=True,
        random_state=100)  # fixing random seed for eval at the same training size     
    for run in range(0, num_runs):  
      x_train_subset, _, y_train_subset, _ = train_test_split(
          x_train, y_train,
          train_size=training_sizes[i],
          shuffle=True,
          random_state=None)             
      model = trainer_fn(x_train_subset, y_train_subset)
      y_pred = model.predict(x_test) 
      accuracy = accuracy_score(y_pred, y_test)    
      result[i] = result[i] + accuracy
    result[i] = result[i] / num_runs            
    print('training size: %i, test accuracy: %.4f' % 
           (training_sizes[i],  result[i]))              
  return result

# %%
training_sizes = [1000, 10000, 25000, 40000,  60000, 80000]
num_runs = 1
result = evaluate_model(df, trainer, 
                              training_sizes, num_runs)
# Out:
# training size: 1000, accuracy: 0.4979
# training size: 10000, accuracy: 0.5823
# training size: 25000, accuracy: 0.7039
# training size: 40000, accuracy: 0.7249
# training size: 60000, accuracy: 0.7699
# training size: 80000, accuracy: 0.7730

# %%
import plotly.express as px
print("this is the accuracy score: \n", result)
result_df = pd.DataFrame()
result_df['train_size'] = training_sizes
result_df['accuracy'] = result
px.line(result_df, x="train_size", y="accuracy", log_x=True)
# Out:
# this is the accuracy score:
#  [0.49790039 0.58227539 0.70385742 0.72490234 0.76987305 0.77299805]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c8a30578-0a9b-4756-ba38-1259259b2dd0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c8a30578-0a9b-4756-ba38-1259259b2dd0")) {                    Plotly.newPlot(                        "c8a30578-0a9b-4756-ba38-1259259b2dd0",                        [{"hovertemplate":"train_size=%{x}<br>accuracy=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[1000,10000,25000,40000,60000,80000],"xaxis":"x","y":[0.497900390625,0.582275390625,0.703857421875,0.72490234375,0.769873046875,0.772998046875],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"t ...
